# %% [markdown]
# # A simple example notebook that demonstrates how to query the database to get an overview of studies and observations

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from visualizations import experimental_overview,get_studies,get_observations

# %% [markdown]
# ### List all studies in database

# %%
s=get_studies()
print s
# Out:
# ['Kwon_1999', 'Krishnan_2009', 'Vierling_2008']

# %% [markdown]
# ### List all observations in database

# %%
o=get_observations()
print o
# Out:
# ['2525 :25 Hz power at 25 Hz drive', '2040 :20 Hz power at 40 Hz drive', '1010 :10 Hz power at 10 Hz drive', '3030 :30 Hz power at 30 Hz drive', '2020 :20 Hz power at 20 Hz drive', '1515 :15 Hz power at 15 Hz drive', '4545 :45 Hz power at 45 Hz drive', '4040 :40 Hz power at 40 Hz drive', '0505 :5 Hz power at 5 Hz drive', '4020 :40 Hz power at 20 Hz drive', '3535 :35 Hz power at 35 Hz drive', '5050 :50 Hz power at 50 Hz drive']

# %% [markdown]
# ## Qualitative representation of studies

# %% [markdown]
# ### Full overview

# %%
experimental_overview()
# Out:
# ([['not tested', 'equal', 'not tested'],
#   ['lower', 'lower', 'lower'],
#   ['higher', 'equal', 'higher'],
#   ['not tested', 'equal', 'not tested'],
#   ['equal', 'equal', 'equal'],
#   ['not tested', 'lower', 'not tested'],
#   ['higher', 'equal', 'higher'],
#   ['lower', 'equal', 'lower'],
#   ['not tested', 'equal', 'not tested'],
#   ['not tested', 'equal', 'not tested'],
#   ['not tested', 'lower', 'not tested'],
#   ['not tested', 'equal', 'not tested']],
#  ['10 Hz power at 10 Hz drive',
#   '45 Hz power at 45 Hz drive',
#   '20 Hz power at 40 Hz drive',
#   '35 Hz power at 35 Hz drive',
#   '40 Hz power at 40 Hz drive',
#   '25 Hz power at 25 Hz drive',
#   '20 Hz power at 20 Hz drive',
#   '30 Hz power at 30 Hz drive',
#   '15 Hz power at 15 Hz drive',
#   '40 Hz power at 20 Hz drive',
#   '50 Hz power at 50 Hz drive',
#   '5 Hz power at 5 Hz drive'],
#  ['Kwon_1999', 'Krishnan_2009', 'Vierling_2008'])

# %% [markdown]
# ### Specific studies

# %%
studies = ['Kwon_1999','Krishnan_2009']
a=experimental_overview(studies=studies)

# %% [markdown]
# ### Specific observations

# %%
observations = ['2020','3030','4040']
experimental_overview(observations=observations)

# %% [markdown]
# ### Specific observations for specific studies

# %%
observations = ['2020','3030','4040']
studies = ['Kwon_1999','Krishnan_2009']
experimental_overview(studies=studies,observations=observations)

# %% [markdown]
# ## Quantitative representation of studies

# %%
experimental_overview(entrytype='Full')

# %% [markdown]
# ### Specific studies

# %%
studies = ['Kwon_1999','Krishnan_2009']
experimental_overview(studies=studies,entrytype='Full')

# %% [markdown]
# ### Specific observations

# %%
observations = ['2020','3030','4040']
experimental_overview(observations=observations,entrytype='Full')

# %% [markdown]
# ### Specific observations for specific studies

# %%
observations = ['2020','3030','4040']
studies = ['Kwon_1999','Krishnan_2009']
experimental_overview(studies=studies,observations=observations,entrytype='Full')

# %% [markdown]
# ### Display meta data

# %%
a=experimental_overview(meta=True)
# Out:
# Kwon_1999
# {   'Comments': 'Values estimated from figures, since values are not provided',
#     'Measure': {   'Location': 'Midline frontal electrode',
#                    'Modality': 'EEG',
#                    'Processing': 'Butterworth bandpass-filtered time averages followed by Fourier transform',
#                    'Value': 'Mean Absolute Power'},
#     'Number of subjects': '15 (Ctrl) and 15 (Scz)',
#     'Paradigm': 'Click-train',
#     'Subjects': 'Schizophrenia vs Control'}
# Krishnan_2009
# {   'Measure': {   'Location': 'Cz in a 10-20 setting',
#                    'Modality': 'EEG',
#                    'Processing': 'Least square linear FIR filtered and Hilbert transformed',
#                    'Value': 'Mean baseline corrected power'},
#     'Number of subjects': '21 (Ctrl) vs 21 (Scz)',
#     'Paradigm': 'Amplitude-modulated tones; carrier freqeuncy 1kHz',
#     'Subjects': 'Schizophrenia vs Control'}
# Vierling_2008
# {   'Comments': 'Values estimated from figures, since values are not provided',
#     'Measure': {   'Location': 'Left hemisphere',
#                    'Modality': 'MEG',
#                    'Processing': 'Time-averaging followed by PSD using Welch`s method',
#                    'Value': 'Mean Absolute Power'},
#     'Number of Subjects': '12 (Ctrl) and 12 (Scz)',
#     'Paradigm': 'Click-train',
#     'Subjects': 'Schizophrenia vs Control'}
